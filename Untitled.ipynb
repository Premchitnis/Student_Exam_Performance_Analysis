# %%
import pandas as pd
import numpy as np

# %%
# Load dataset
df = pd.read_csv("C:/Users/premc/Downloads/project2/raw_data.csv/StudentPerformanceFactors_p2.csv")

# Quick view
df.head()
# Out:
#    Student_id  Hours_Studied  Attendance Parental_Involvement  \
# 0        1001             23          84                  Low
# 1        1002             19          64                  Low
# 2        1003             24          98               Medium
# 3        1004             29          89                  Low
# 4        1005             19          92               Medium
#
#   Access_to_Resources Extracurricular_Activities  Sleep_Hours  \
# 0                High                         No            7
# 1              Medium                         No            8
# 2              Medium                        Yes            7
# 3              Medium                        Yes            8
# 4              Medium                        Yes            6
#
#    Previous_Scores Motivation_Level Internet_Access  ...  Family_Income  \
# 0               73              Low             Yes  ...            Low
# 1               59              Low             Yes  ...         Medium
# 2               91           Medium             Yes  ...         Medium
# 3               98           Medium             Yes  ...         Medium
# 4               65           Medium             Yes  ...         Medium
#
#   Teacher_Quality School_Type Peer_Influence Physical_Activity  \
# 0          Medium      Public       Positive                 3
# 1          Medium      Public       Negative                 4
# 2          Medium      Public        Neutral                 4
# 3          Medium      Public       Negative                 4
# 4            High      Public        Neutral                 4
#
#    Learning_Disabilities Parental_Education_Level Distance_from_Home  Gender  \
# 0                     No              High School               Near    Male
# 1                     No                  College           Moderate  Female
# 2                     No             Postgraduate               Near    Male
# 3                     No              High School           Moderate    Male
# 4                     No                  College               Near  Female
#
#   Exam_Score
# 0         67
# 1         61
# 2         74
# 3         71
# 4         70
#
# [5 rows x 21 columns]

# %%
# Check duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Remove duplicates
df = df.drop_duplicates()

# Confirm
df.duplicated().sum()
# Out:
# 0

# %%
df['Exam_Score'].isnull().sum()
# Out:
# 0

# %%
df = df.dropna(subset=['Exam_Score'])

# %%
df['Attendance'].isnull().sum()
# Out:
# 0

# %%
df = df.dropna(subset=['Attendance'])

# %%
df['Hours_Studied'].isnull().sum()
# Out:
# 0

# %%
df = df.dropna(subset=['Hours_Studied'])

# %%
df['Previous_Scores'].isnull().sum()
# Out:
# 0

# %%
median_prev = df['Previous_Scores'].median()
df['Previous_Scores'] = df['Previous_Scores'].fillna(median_prev)

# %%
df['Motivation_Level'].isnull().sum()
# Out:
# 0

# %%
df['Motivation_Level'] = df['Motivation_Level'].fillna("Unknown")

# %%
df['Tutoring_Sessions'].isnull().sum()
# Out:
# 0

# %%
df['Tutoring_Sessions'] = df['Tutoring_Sessions'].fillna(0)

# %%
def performance_level(score):
    if score >= 75:
        return "Top Performer"
    elif score >= 50:
        return "Average Performer"
    else:
        return "Weak Performer"

df['Performance_Level'] = df['Exam_Score'].apply(performance_level)

# %%
df.head()
# Out:
#    Student_id  Hours_Studied  Attendance Parental_Involvement  \
# 0        1001             23          84                  Low
# 1        1002             19          64                  Low
# 2        1003             24          98               Medium
# 3        1004             29          89                  Low
# 4        1005             19          92               Medium
#
#   Access_to_Resources Extracurricular_Activities  Sleep_Hours  \
# 0                High                         No            7
# 1              Medium                         No            8
# 2              Medium                        Yes            7
# 3              Medium                        Yes            8
# 4              Medium                        Yes            6
#
#    Previous_Scores Motivation_Level Internet_Access  ...  Teacher_Quality  \
# 0               73              Low             Yes  ...           Medium
# 1               59              Low             Yes  ...           Medium
# 2               91           Medium             Yes  ...           Medium
# 3               98           Medium             Yes  ...           Medium
# 4               65           Medium             Yes  ...             High
#
#   School_Type Peer_Influence Physical_Activity Learning_Disabilities  \
# 0      Public       Positive                 3                    No
# 1      Public       Negative                 4                    No
# 2      Public        Neutral                 4                    No
# 3      Public       Negative                 4                    No
# 4      Public        Neutral                 4                    No
#
#    Parental_Education_Level Distance_from_Home  Gender Exam_Score  \
# 0               High School               Near    Male         67
# 1                   College           Moderate  Female         61
# 2              Postgraduate               Near    Male         74
# 3               High School           Moderate    Male         71
# 4                   College               Near  Female         70
#
#    Performance_Level
# 0  Average Performer
# 1  Average Performer
# 2  Average Performer
# 3  Average Performer
# 4  Average Performer
#
# [5 rows x 22 columns]

# %%
# Check missing values in important columns
df[
    ['Exam_Score', 'Attendance', 'Hours_Studied',
     'Previous_Scores', 'Motivation_Level',
     'Tutoring_Sessions', 'Performance_Level']
].isnull().sum()
# Out:
# Exam_Score           0
# Attendance           0
# Hours_Studied        0
# Previous_Scores      0
# Motivation_Level     0
# Tutoring_Sessions    0
# Performance_Level    0
# dtype: int64

# %%
df.to_excel("student_performance_cleaned.xlsx", index=False)
df.to_csv("student_performance_cleaned.csv", index=False)
